# %%
import torch
from glob import glob

# %%
# yolov5 다운로드 
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# 학습 가중치 파일 폴더에 저장

# %%
# 추론하기 
from IPython.display import Image
import os

# %cd C:/Users/crid2/yolov5/


# !python detect.py  --weights C:/Users/crid2/yolov5/test01/220531_best.pt \
 --img 416 --conf 0.2 --source C:/Users/crid2/Downloads/Closet_Management_proj-main/Bigdata_crawling/images\cody
# Out:
# C:\Users\crid2\yolov5
# detect: weights=['C:/Users/crid2/yolov5/test01/220531_best.pt'], source=C:/Users/crid2/Downloads/Closet_Management_proj-main/Bigdata_crawling/images\cody, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.1-242-ga80dd66 Python-3.9.7 torch-1.10.1 CUDA:0 (NVIDIA GeForce GTX 970, 4096MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/60 C:\Users\crid2\Downloads\Closet_Management_proj-main\Bigdata_crawling\images\cody\cody1.jpg: 416x288 1 slack, Done. (0.016s)
# ...
