# %%
# yolov5 다운로드 
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# 학습 가중치 파일 폴더에 저장 
# yolov5/test03 폴더 생성후 *.pt 가중치 파일 저장

# %%
# 이미지 폴더

#cody 
cody = C:/Users/crid2/Downloads/Closet_Management_proj-main/Bigdata_crawling/images/cody

bottom_cotton = C:/Users/crid2/Downloads/Closet_Management_proj-main/Bigdata_crawling/images/bottom_cotton
bottom_jean = C:/Users/crid2/Downloads/Closet_Management_proj-main/Bigdata_crawling/images/bottom_jean
bottom_jogger = C:/Users/crid2/Downloads/Closet_Management_proj-main/Bigdata_crawling/images/bottom_jogger 
bottom_shorts = C:/Users/crid2/Downloads/Closet_Management_proj-main/Bigdata_crawling/images/bottom_shorts 
bottom_slacks = C:/Users/crid2/Downloads/Closet_Management_proj-main/Bigdata_crawling/images/bottom_slacks
top_long = C:/Users/crid2/Downloads/Closet_Management_proj-main/Bigdata_crawling/images/top_long
top_short = C:/Users/crid2/Downloads/Closet_Management_proj-main/Bigdata_crawling/images/top_short
# Out:
#   Input In [5]
#     cody = C:/Users/crid2/Downloads/Closet_Management_proj-main/Bigdata_crawling/images/cody
#             ^
# SyntaxError: invalid syntax

# %%
# 추론하기 
from IPython.display import Image
import os

#--source 이미지 주소
#--weight 가중치 *.pt 파일 주소 
    #classes 0 , 1 클래스 확인후 특정 숫자만  지정하면 클래스 필터가능 
    #save-txt 라벨 좌표 저장 labels로 저장됨 중요 , 라벨링 앞에 0,1 ,2 클래스 생성되므로 나중에 수정필요함
    #save-crop 특정 사진만 잘라서 저장 라벨링이 아닌 그냥 

# %cd C:/Users/crid2/yolov5/

# !python detect.py  --weights C:/Users/crid2/yolov5/test03/three_clasfication_large.pt \
 --save-txt --save-conf --save-crop  --line-thickness 2 \
 --img 416 --conf 0.4 --source C:/Users/crid2/Downloads/Closet_Management_proj-main/Bigdata_crawling/images/cody
# Out:
# C:\Users\crid2\yolov5
# detect: weights=['C:/Users/crid2/yolov5/test03/three_clasfication_large.pt'], source=C:/Users/crid2/Downloads/Closet_Management_proj-main/Bigdata_crawling/images/cody, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=2, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.1-242-ga80dd66 Python-3.9.7 torch-1.10.1 CUDA:0 (NVIDIA GeForce GTX 970, 4096MiB)
#
# Fusing layers...
# YOLOv5l summary: 367 layers, 46119048 parameters, 0 gradients, 107.8 GFLOPs
# image 1/60 C:\Users\crid2\Downloads\Closet_Management_proj-main\Bigdata_crawling\images\cody\cody1.jpg: 416x288 1 bottom, 1 top, Done. (0.032s)
# ...

# %%
''' usage: detect.py [-h] [--weights WEIGHTS [WEIGHTS ...]] [--source SOURCE]
                 [--data DATA] [--imgsz IMGSZ [IMGSZ ...]]
                 [--conf-thres CONF_THRES] [--iou-thres IOU_THRES]
                 [--max-det MAX_DET] [--device DEVICE] [--view-img]
                 [--save-txt] [--save-conf] [--save-crop] [--nosave]
                 [--classes CLASSES [CLASSES ...]] [--agnostic-nms]
                 [--augment] [--visualize] [--update] [--project PROJECT]
                 [--name NAME] [--exist-ok] [--line-thickness LINE_THICKNESS]
                 [--hide-labels] [--hide-conf] [--half] [--dnn] '''

# %%
# label data 전처리 , 맨앞 클래스 번호 0,1,2 -> 맞는 클래스로 정의해야함 
import pandas as pd 
from glob import glob

# %%
# 라벨 txt 파일 주소를 리스트 화 
label_list = glob('C:/Users/crid2/yolov5/runs/detect/exp8/labels/*.txt')
print(len(label_list))
# Out:
# 0

# %%
for i in range(len(label_list)) : 
    test_label = pd.read_csv(label_list[i], sep=' ', header = None)
    print(label_list[i])
    test_label[0] = 100
    test_label.to_csv(label_list[i],index=False,sep=' ' , header=None)
