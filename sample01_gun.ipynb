# %% [markdown]
# <a href="https://colab.research.google.com/github/likeaAI/pytorch/blob/main/sample01_gun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 로보플로우 데이타셋 다운로드 
# !curl -L "https://public.roboflow.com/ds/bfTB1gwdiQ?key=DYdiBbFvlP" > \
roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
# yolov5 다운로드 
# %cd /content
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12128, done.
# remote: Total 12128 (delta 0), reused 0 (delta 0), pack-reused 12128
# Receiving objects: 100% (12128/12128), 11.88 MiB | 29.90 MiB/s, done.
# Resolving deltas: 100% (8399/8399), done.

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# %cat /content/dataset/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 1
# names: ['pistol']

# %%
# 다운로드 이미지파일 전체 인식 
# %cd /
from glob import glob

img_list = glob('/content/dataset/export/images/*.jpg')

print(len(img_list))
# Out:
# /
# 2971

# %%
from sklearn.model_selection import train_test_split
train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state=20000)
print(len(train_img_list), len(val_img_list))
# Out:
# 2376 595

# %%
with open('/content/dataset/train.txt' , 'w') as f : 
  f.write('\n'.join(train_img_list))

# %%
with open('/content/dataset/val.txt' , 'w') as f : 
  f.write('\n'.join(val_img_list))

# %%
import yaml

with open('/content/dataset/data.yaml' , 'r') as f : 
  data = yaml.load(f)

print(data)


data['train'] = '/content/dataset/train.txt'
data['val'] = '/content/dataset/val.txt'

with open ('/content/dataset/data.yaml' , 'w') as f : 
  yaml.dump(data, f )

print(data)
# Out:
# {'names': ['pistol'], 'nc': 1, 'train': '/content/dataset/train.txt', 'val': '/content/dataset/val.txt'}
# {'names': ['pistol'], 'nc': 1, 'train': '/content/dataset/train.txt', 'val': '/content/dataset/val.txt'}

# %%
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 50 \
--data /content/dataset/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt \
--name gun_yolov5s_result
# Out:
# /content/yolov5
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/content/dataset/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=gun_yolov5s_result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-236-gdcf8073 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
